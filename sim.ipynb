# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Apr 17 11:26:58 2025

@author: olive
"""
# Out:
# '\nCreated on Thu Apr 17 11:26:58 2025\n\n@author: olive\n'

# %%
# Stabilization and dynamics of superfluid vortices in a neutron star

# %%
# Ported from C++ by Oliver Wilson with the help of ChatGPT

# %%
import os

# %%
import math

# %%
import random

# %%
import time

# %%
from pathlib import Path

# %%
import numpy as np

# %%
# ----- Shorthands are removed in Python (use functions instead) -----

# %%
# ----- Directory for outputs -----
path = "./InOut/"  # Make sure this directory exists
pathplace = ""
numb_runs = 5
run_id = 1

# %%
# ----- Constants and parameters -----

pi = math.pi

# %%
# Basic parameters
nv = 2000
npin_desired = 20000
numb_trig = 0
R = 10
k = 1.0
phi = 0.1
V_1 = 2000
V_2 = 2000
trig_duration = 0
decel = -0.25e-3
stab_time = 100
sim_time = 2000
trig_type = "stresswave"

# %%
# Advanced parameters
pin_config = "annular"
trig_region = "fullsector"
write_fullpos = False
k_img = k
omega_0 = (nv * k) / (R * R)
T_0 = (2 * pi) / omega_0
a = R * math.sqrt(pi / npin_desired)
Xi = 0.1 * a
N_ext_0 = decel * (omega_0 / T_0)
n_ratio = 1
r_annulus = R / math.sqrt(2)
duration_trig = trig_duration * T_0
runtime_stabilization = stab_time * T_0
runtime_simulation = sim_time * T_0
del_t = 5e-3
N_ext = N_ext_0
omega_c = omega_0
omega_s = omega_0
sector_count = 8
stresswave_threshold = 0.7
epsilon_glitch = 1e-12

# %%
# ----- Initial variables -----

npin = 0
vortex_out_count = 0
nmax = int(math.floor(2 * R / a) + 1)
type_counter = 0
trial_count = 0
count_trig = 0
state_trig = 0
unpinned_count = 0
vortex_in_count = 0
H = 0
kiss = 0
prog = 0
time_start_trig = 0
t = 0

# %%
# ----- Initial vectors -----

f = []  # state vector

vortex_vectx = [0.0] * nv
vortex_vecty = [0.0] * nv
imgvortex_vectx = [0.0] * nv
imgvortex_vecty = [0.0] * nv
K = [k] * nv
K_img = [k_img] * nv
omega_s_vector = [omega_0]
omega_c_vector = [omega_0]
V_0 = [[0.0 for _ in range(nmax)] for _ in range(nmax)]
V_0_original = [[0.0 for _ in range(nmax)] for _ in range(nmax)]
times_trig = [0.0] * numb_trig
omega_s_forsum = [0.0] * nv

# %%
# Backups for reinitialization
i_vortex_vectx = list(vortex_vectx)
i_vortex_vecty = list(vortex_vecty)
i_imgvortex_vectx = list(imgvortex_vectx)
i_imgvortex_vecty = list(imgvortex_vecty)
i_K = list(K)
i_K_img = list(K_img)
i_omega_s_vector = list(omega_s_vector)
i_omega_c_vector = list(omega_c_vector)
i_V_0 = [row[:] for row in V_0]
i_V_0_original = [row[:] for row in V_0_original]
i_times_trig = list(times_trig)
i_omega_s_forsum = list(omega_s_forsum)

# %%
# Output tracking
Hvalues = []
tvalues = []
vortex_states = []
omega_c_vec = []
omega_s_vec = []
numboff_vec = []
sector_vec = []
unpinned_vec = []
vortex_in_vec = []

# %%
#Simulation loop

# %%
def run_simulation():
    global run_id

    for run_id in range(1, numb_runs + 1):
        print(f"Run {run_id} of {numb_runs}")

        # Initial resets
        reinitialize()

        # Create output directory and initialize files
        create_output_files(run_id)
        vortexinit1()
        initial_state()
        circulation_init()
        vortex_counter()
        pin_config_set()
        pins_count()
        write_info_start()
        stabilization()
        write_data_post_stabilization()
        t = 0
        tvalues.clear()
        prog = 0
        trig_init()
        vortex_counter()
        kiss_fix()
        write_info_mid()
        simulation()
        write_info_end()
        write_data_post_simulation()
        find_glitch(omega_c_vec, tvalues, epsilon_glitch)

        print("Done with run.\n")

# %%
#Reinitializing variables function

# %%
def reinitialize():
    global N_ext, omega_c, omega_s
    global npin, vortex_out_count, nmax, type_counter, trial_count
    global count_trig, state_trig, unpinned_count, vortex_in_count
    global H, kiss, prog, time_start_trig, t
    global f, vortex_vectx, vortex_vecty, imgvortex_vectx, imgvortex_vecty
    global K, K_img, omega_s_vector, omega_c_vector
    global V_0, V_0_original, times_trig, omega_s_forsum
    global Hvalues, tvalues, vortex_states
    global omega_c_vec, omega_s_vec, numboff_vec
    global sector_vec, unpinned_vec, vortex_in_vec

    # Scalar resets
    N_ext = N_ext_0
    omega_c = omega_0
    omega_s = omega_0

    npin = 0
    vortex_out_count = 0
    nmax = int(math.floor(2 * R / a) + 1)
    type_counter = 0
    trial_count = 0
    count_trig = 0
    state_trig = 0
    unpinned_count = 0
    vortex_in_count = 0
    H = 0
    kiss = 0
    prog = 0
    time_start_trig = 0
    t = 0

    # Vector resets
    vortex_vectx = list(i_vortex_vectx)
    vortex_vecty = list(i_vortex_vecty)
    imgvortex_vectx = list(i_imgvortex_vectx)
    imgvortex_vecty = list(i_imgvortex_vecty)
    K = list(i_K)
    K_img = list(i_K_img)
    omega_s_vector = list(i_omega_s_vector)
    omega_c_vector = list(i_omega_c_vector)
    V_0 = [row[:] for row in i_V_0]
    V_0_original = [row[:] for row in i_V_0_original]
    times_trig = list(i_times_trig)
    omega_s_forsum = list(i_omega_s_forsum)

    # Output vectors
    f.clear()
    Hvalues.clear()
    tvalues.clear()
    vortex_states.clear()
    omega_c_vec.clear()
    omega_s_vec.clear()
    numboff_vec.clear()
    sector_vec.clear()
    unpinned_vec.clear()
    vortex_in_vec.clear()

# %%
#output files

# %%
def create_output_files(run_id):
    global pathplace
    var = str(run_id)
    pathplace = os.path.join(path, f"run{var}/")
    Path(pathplace).mkdir(parents=True, exist_ok=True)

    def init_file(filename, header=None):
        fullpath = os.path.join(pathplace, filename)
        with open(fullpath, 'w') as f:
            if header:
                f.write(header + '\n')

    init_file("sim_vortex_pos.dat", "t/T_0\t" + "\t".join([f"x{i+1}" for i in range(nv)] + [f"y{i+1}" for i in range(nv)]))
    init_file("sim_vortex_pos_minimal.dat", "t/T_0\t" + "\t".join([f"x{i+1}" for i in range(nv)] + [f"y{i+1}" for i in range(nv)]))
    init_file("init_vortex_pos.dat", "x\ty")
    init_file("init_img_pos.dat", "x\ty")
    init_file("stabilized_Hvalues.dat", "t/T_0\tH")
    init_file("stabilized_vortex_pos.dat")
    init_file("sim_omega_c.dat", "t/T_0\tomega_c/omega_0")
    init_file("sim_omega_s.dat", "t/T_0\tomega_s/omega_0")
    init_file("info_simulation.dat")
    init_file("info_progress.dat")
    init_file("sim_triggers.dat", "t/T_0\tsector_id\tnumboff" if trig_type == "sectorial" else "t/T_0")
    init_file("sim_unpinned.dat", "t/T_0\tunpinned_count\ttotal_count\tunpinned_frac")
    init_file("info_glitch.dat")
    init_file("data_glitch.dat")

# %%
def write_progress(runtime, phase_label="Phase", step_fraction=0.01):
    global prog
    percent_done = ((t / runtime) * 100)

    if percent_done >= prog + 0.01:
        prog = percent_done
        msg = f"{phase_label} progress: {prog}% complete"
        print(msg)  # Console output
        with open(os.path.join(pathplace, "info_progress.dat"), "a") as f:
            f.write(msg + "\n")

# %%
def vortexinit1():
    global vortex_vectx, vortex_vecty, imgvortex_vectx, imgvortex_vecty

    for i in range(nv):
        r = R * math.sqrt(random.uniform(0, 1))
        theta = 2 * pi * random.uniform(0, 1)

        x = r * math.cos(theta)
        y = r * math.sin(theta)

        vortex_vectx[i] = x
        vortex_vecty[i] = y

        r_img = R**2 / r
        x_img = r_img * math.cos(theta)
        y_img = r_img * math.sin(theta)

        imgvortex_vectx[i] = x_img
        imgvortex_vecty[i] = y_img

    # Write to file
    with open(os.path.join(pathplace, "init_vortex_pos.dat"), "a") as fout_v, \
         open(os.path.join(pathplace, "init_img_pos.dat"), "a") as fout_i:
        for i in range(nv):
            fout_v.write(f"{vortex_vectx[i]:.15f}\t{vortex_vecty[i]:.15f}\n")
            fout_i.write(f"{imgvortex_vectx[i]:.15f}\t{imgvortex_vecty[i]:.15f}\n")

# %%
def initial_state():
    global f
    f = vortex_vectx + vortex_vecty  # concatenate x and y positions

# %%
def circulation_init():
    global K, K_img

    for i in range(nv):
        r = math.hypot(f[i], f[i + nv])
        if r > R:
            K[i] = 0
            K_img[i] = 0
        else:
            K[i] = k
            K_img[i] = k

# %%
def vortex_counter():
    global vortex_out_count, vortex_in_count, unpinned_count

    vortex_out_count = 0
    vortex_in_count = 0
    unpinned_count = 0

    for i in range(nv):
        xi = f[i]
        yi = f[i + nv]
        r = math.hypot(xi, yi)

        if r >= R:
            vortex_out_count += 1
        else:
            vortex_in_count += 1

            x_pin_nearest = -R + round((xi + R) / a) * a
            y_pin_nearest = -R + round((yi + R) / a) * a
            r_pin_nearest = math.hypot(x_pin_nearest - xi, y_pin_nearest - yi)

            if r_pin_nearest > Xi:
                unpinned_count += 1

# %%
def pin_strength_initialize_annular():
    global V_0
    for x in np.arange(-R, R + a, a):
        for y in np.arange(-R, R + a, a):
            dist_pin = math.hypot(x, y)
            if dist_pin < R:
                nx = round((R + x) / a)
                ny = round((R + y) / a)
                if dist_pin <= r_annulus:
                    V_0[nx][ny] = V_1
                else:
                    V_0[nx][ny] = V_2

# %%
def pin_strength_initialize_half():
    global V_0
    for x in np.arange(-R, R + a, a):
        for y in np.arange(-R, R + a, a):
            dist_pin = math.hypot(x, y)
            if dist_pin < R:
                nx = round((R + x) / a)
                ny = round((R + y) / a)
                V_0[nx][ny] = V_1 if x < 0 else V_2

# %%
def pin_strength_initialize_alternate():
    global V_0, type_counter
    type_counter = 0
    for x in np.arange(-R, R + a, a):
        for y in np.arange(-R, R + a, a):
            dist_pin = math.hypot(x, y)
            if dist_pin < R:
                nx = round((R + x) / a)
                ny = round((R + y) / a)
                if type_counter != n_ratio:
                    V_0[nx][ny] = V_1
                    type_counter += 1
                else:
                    V_0[nx][ny] = V_2
                    type_counter = 0

# %%
def pin_config_set():
    global V_0_original

    if pin_config == "half":
        pin_strength_initialize_half()
    elif pin_config == "alternate":
        pin_strength_initialize_alternate()
    elif pin_config == "annular":
        pin_strength_initialize_annular()
    
    # Save original for reset after trigger
    V_0_original = [row[:] for row in V_0]

# %%
def pins_count():
    global npin
    npin = 0
    for x in np.arange(-R, R + a, a):
        for y in np.arange(-R, R + a, a):
            if math.hypot(x, y) < R:
                npin += 1

# %%
def write_info_start():
    with open(os.path.join(pathplace, "info_simulation.dat"), "a") as f:
        f.write(f"nv = {nv}\n")
        f.write(f"npin = {npin}\n")
        f.write(f"pin_config = {pin_config}\n")
        f.write(f"r_annulus = {r_annulus / R:.4f} R\n")
        f.write(f"R = {R}\n")
        f.write(f"omega_0 = {omega_0}\n")
        f.write(f"T_0 = {T_0}\n")
        f.write(f"phi = {phi}\n")
        f.write(f"V_1 = {V_1}\n")
        f.write(f"V_2 = {V_2}\n")
        f.write(f"n_ratio = {n_ratio}\n")
        f.write(f"a = {a / R:.4f} R\n")
        f.write(f"Xi = {Xi / R:.4f} R\n")
        f.write(f"N_ext = {N_ext * (T_0 / omega_0):.6f} omega_0/T_0\n")
        f.write(f"initial del_t = {del_t / T_0:.6f} T_0\n\n")
        f.write(f"trig_region = {trig_region}\n")
        f.write(f"numb_trig = {numb_trig}\n")
        f.write(f"duration_trig = {duration_trig / T_0:.6f} T_0\n")
        f.write(f"sector_count = {sector_count}\n")
        f.write(f"trig_type = {trig_type}\n")
        f.write(f"Stabilization runtime = {runtime_stabilization / T_0:.2f} T_0\n\n")
        f.write(f"Simulation runtime = {runtime_simulation / T_0:.2f} T_0\n\n")
        f.write(f"Start time = {time.ctime()}\n")
        f.write(f"nv_out = {vortex_out_count}\n\n")

# %%
def stabilization():
    global t
    while t <= runtime_stabilization:
        write_progress(runtime_stabilization, "Stabilization")
        tvalues.append(t / T_0)
        H_calculate_save()

        integ_adaptive()
        t += del_t

        updates(omega_s_condition=0)  # update image vortices + circulation (no omega_s in stab)

# %%
def H_calculate_save():
    global H, Hvalues
    H_forsum = []

    for i in range(nv):
        h_i = 0
        xi, yi = f[i], f[i + nv]
        for j in range(nv):
            if j != i:
                xj, yj = f[j], f[j + nv]
                rij = math.hypot(xi - xj, yi - yj)
                h_i += math.log(rij)
        H_forsum.append(h_i)

    H = sum(H_forsum)
    Hvalues.append(H)

# %%
from scipy.integrate import solve_ivp

# %%
def integ_adaptive():
    global f
    t_span = (t, t + del_t)
    f0 = np.array(f)

    sol = solve_ivp(fun=eom_wrapper, t_span=t_span, y0=f0, method="RK45", rtol=1e-5, atol=1e-8)

    if sol.success:
        f[:] = sol.y[:, -1].tolist()
    else:
        print("Integration failed.")

# %%
def eom_wrapper(t, f_local):
    dfdt = [0.0] * (2 * nv)

    for i in range(nv):
        xi = f_local[i]
        yi = f_local[i + nv]

        if K[i] == 0:
            continue

        dxdt = omega_c * yi
        dydt = -omega_c * xi
        Ki = K[i]

        for j in range(nv):
            if i == j or K[j] == 0:
                continue
            xj, yj = f_local[j], f_local[j + nv]
            dx = xi - xj
            dy = yi - yj
            r2 = dx**2 + dy**2
            dxdt += -K[j] * Ki * dy / r2
            dydt += K[j] * Ki * dx / r2

            dx_img = xi - imgvortex_vectx[j]
            dy_img = yi - imgvortex_vecty[j]
            r2_img = dx_img**2 + dy_img**2
            dxdt += K_img[j] * Ki * dy_img / r2_img
            dydt += -K_img[j] * Ki * dx_img / r2_img

        nx = int(round((xi + R) / a))
        ny = int(round((yi + R) / a))
        if nx <= 0 or ny <= 0 or nx >= nmax or ny >= nmax:
            nx, ny = 0, 0

        x_pin = -R + round((xi + R) / a) * a
        y_pin = -R + round((yi + R) / a) * a
        r2_pin = (x_pin - xi)**2 + (y_pin - yi)**2
        dxdt += V_0[nx][ny] * math.exp(-r2_pin / (2 * Xi**2)) * (yi - y_pin)
        dydt += -V_0[nx][ny] * math.exp(-r2_pin / (2 * Xi**2)) * (xi - x_pin)

        # Apply dissipation
        vel_x = dxdt * K[i]
        vel_y = dydt * K[i]
        dfdt[i] = math.cos(phi) * vel_x + math.sin(phi) * vel_y
        dfdt[i + nv] = -math.sin(phi) * vel_x + math.cos(phi) * vel_y

    return dfdt

# %%
def updates(omega_s_condition):
    for i in range(nv):
        if K[i] == 0:
            continue

        xi = f[i]
        yi = f[i + nv]
        r = math.hypot(xi, yi)
        theta = math.atan2(yi, xi)

        r_img = R**2 / r
        imgvortex_vectx[i] = r_img * math.cos(theta)
        imgvortex_vecty[i] = r_img * math.sin(theta)

        if r > R:
            K[i] = 0
            K_img[i] = 0
        else:
            K[i] = k
            K_img[i] = k

        if omega_s_condition == 1:
            omega_s_forsum[i] = K[i] * kiss * (R**2 - r**2)

    if omega_s_condition == 1:
        global omega_s
        omega_s = sum(omega_s_forsum)
        omega_s_vector.append(omega_s)
        vortex_counter()

# %%
def write_data_post_stabilization():
    # Write final vortex positions
    with open(os.path.join(pathplace, "stabilized_vortex_pos.dat"), "a") as f_pos:
        f_pos.write("x\ty\n")
        for i in range(nv):
            f_pos.write(f"{f[i]:.15f}\t{f[i + nv]:.15f}\n")
        f_pos.write("\n")

    # Write H values vs time
    with open(os.path.join(pathplace, "stabilized_Hvalues.dat"), "a") as f_H:
        for t_val, H_val in zip(tvalues, Hvalues):
            f_H.write(f"{t_val:.15f}\t{H_val:.15f}\n")

# %%
def trig_init():
    global times_trig
    times_trig = sorted([random.uniform(0, runtime_simulation) for _ in range(numb_trig)])
    times_trig.append(runtime_simulation + 5)  # ensures no trigger happens past sim time

# %%
def kiss_fix():
    global kiss
    total = 0
    for i in range(nv):
        xi = f[i]
        yi = f[i + nv]
        r = math.hypot(xi, yi)
        if r < R:
            total += R**2 - r**2
    kiss = omega_0 / total if total != 0 else 0

# %%
def write_info_mid():
    with open(os.path.join(pathplace, "info_simulation.dat"), "a") as f:
        f.write(f"Stabilization end time = {time.ctime()}\n\n")
        f.write("Simulation begins.\n")
        f.write(f"nv_out = {vortex_out_count}\n")
        f.write(f"unpinned_count = {unpinned_count}\n")
        f.write(f"omega_c = {omega_c / omega_0:.6f} omega_0\n\n")
        f.write(f"k/I_s = {kiss:.6f}\n\n\n")

# %%
def simulation():
    global t, omega_c

    while t <= runtime_simulation:
        write_progress(runtime_simulation, "Simulation")

        tvalues.append(t / T_0)
        vortex_states.append(list(f))  # copy current state
        omega_c_vec.append(omega_c / omega_0)
        omega_s_vec.append(omega_s / omega_0)
        unpinned_vec.append(unpinned_count)
        vortex_in_vec.append(vortex_in_count)

        # Trigger handling
        if trig_duration != 0:
            trigger_check(duration_trig, t)

        # Crust spindown
        omega_c += N_ext * del_t

        # Integrate system
        integ_adaptive()
        t += del_t

        # Update circulations, image vortices, etc.
        updates(omega_s_condition=1)

        # Feedback from superfluid to crust
        if len(omega_s_vector) >= 2:
            delta_omega_s = omega_s_vector[-1] - omega_s_vector[-2]
            omega_c -= delta_omega_s

# %%
def write_info_end():
    with open(os.path.join(pathplace, "info_simulation.dat"), "a") as f:
        f.write(f"End time = {time.ctime()}\n")
        f.write(f"nv_out = {vortex_out_count}\n")
        f.write(f"omega_c = {omega_c / omega_0:.6f} omega_0\n\n\n")

# %%
def write_vortex_positions():
    # Full position data (optional based on flag)
    if write_fullpos:
        with open(os.path.join(pathplace, "sim_vortex_pos.dat"), "a") as f:
            for i in range(len(tvalues)):
                pos = "\t".join(f"{x:.15f}" for x in vortex_states[i])
                f.write(f"{tvalues[i]:.15f}\t{pos}\n")

    # Minimal (every 10th timestep)
    with open(os.path.join(pathplace, "sim_vortex_pos_minimal.dat"), "a") as f:
        for i in range(0, len(tvalues), 10):
            pos = "\t".join(f"{x:.15f}" for x in vortex_states[i])
            f.write(f"{tvalues[i]:.15f}\t{pos}\n")

# %%
def write_omega_series():
    with open(os.path.join(pathplace, "sim_omega_c.dat"), "a") as f_c, \
         open(os.path.join(pathplace, "sim_omega_s.dat"), "a") as f_s:
        for t_val, oc, os in zip(tvalues, omega_c_vec, omega_s_vec):
            f_c.write(f"{t_val:.15f}\t{oc:.15f}\n")
            f_s.write(f"{t_val:.15f}\t{os:.15f}\n")

# %%
def write_triggers():
    filepath = os.path.join(pathplace, "sim_triggers.dat")
    with open(filepath, "a") as f:
        if trig_type == "sectorial":
            for t_val, sid, off in zip(times_trig[:-1], sector_vec, numboff_vec):
                f.write(f"{t_val / T_0:.15f}\t{sid}\t{off}\n")
        elif trig_type == "stresswave":
            for t_val in times_trig[:-1]:
                f.write(f"{t_val / T_0:.15f}\n")

# %%
def write_unpinned():
    with open(os.path.join(pathplace, "sim_unpinned.dat"), "a") as f:
        for t_val, unpinned, inside in zip(tvalues, unpinned_vec, vortex_in_vec):
            frac = unpinned / inside if inside != 0 else 0
            f.write(f"{t_val:.15f}\t{unpinned}\t{inside}\t{frac:.6f}\n")

# %%
def write_data_post_simulation():
    write_vortex_positions()
    write_omega_series()
    write_triggers()
    write_unpinned()

# %%
def trigger_check(duration_trig, t_curr):
    global time_start_trig, state_trig, count_trig, V_0

    if trig_type == "stresswave":
        if t_curr > times_trig[count_trig]:
            time_start_trig = t_curr
            state_trig = 1
            count_trig += 1
            pin_reduce()

        if state_trig == 1 and t_curr > time_start_trig + duration_trig:
            state_trig = 0
            V_0 = [row[:] for row in V_0_original]

    elif trig_type == "sectorial":
        if t_curr > times_trig[count_trig]:
            time_start_trig = t_curr
            state_trig = 1
            count_trig += 1
            pin_off()

        if state_trig == 1 and t_curr > time_start_trig + duration_trig:
            state_trig = 0
            V_0 = [row[:] for row in V_0_original]

# %%
def pin_off():
    numboff = 0
    sector_id = int(random.uniform(0, sector_count))
    sector_vec.append(sector_id)

    for x in np.arange(-R, R + a, a):
        for y in np.arange(-R, R + a, a):
            dist_pin = math.hypot(x, y)
            if dist_pin >= R:
                continue

            nx = round((R + x) / a)
            ny = round((R + y) / a)

            if trig_region == "outer" and dist_pin <= r_annulus:
                continue
            if trig_region == "inner" and dist_pin > r_annulus:
                continue

            if sector_check(x, y, sector_id) and random.random() <= 0.5:
                V_0[nx][ny] = 0
                numboff += 1

    numboff_vec.append(numboff)

# %%
def pin_reduce():
    for x in np.arange(-R, R + a, a):
        for y in np.arange(-R, R + a, a):
            if math.hypot(x, y) >= R:
                continue
            nx = round((R + x) / a)
            ny = round((R + y) / a)
            V_0[nx][ny] = stresswave_threshold * V_1

# %%
def sector_check(x, y, sector_id):
    angle = math.degrees(math.atan2(y if y != 0 else 1e-6, x if x != 0 else 1e-6))
    if angle < 0:
        angle += 360

    angle_start = sector_id * (360 / sector_count)
    angle_end = angle_start + (360 / sector_count)

    return angle_start < angle < angle_end

# %%
def find_glitch(omega_vec, t_vec, epsilon):
    glitch_state = False
    glitch_init = False

    t_i = omega_i = t_f = omega_f = 0
    t_glitch = []
    t_rise = []
    del_omega = []

    for i in range(1, len(t_vec)):
        omegadot = (omega_vec[i] - omega_vec[i - 1]) / (t_vec[i] - t_vec[i - 1])
        if not glitch_state and omegadot > 0:
            glitch_state = True
            glitch_init = True
        elif glitch_state and omegadot < 0:
            glitch_state = False
            t_f = t_vec[i - 1]
            omega_f = omega_vec[i - 1]
            delta = omega_f - omega_i
            if delta > epsilon:
                t_glitch.append(t_i)
                t_rise.append(t_f - t_i)
                del_omega.append(delta)

        if glitch_init:
            t_i = t_vec[i - 1]
            omega_i = omega_vec[i - 1]
            glitch_init = False

    # Waiting times
    t_wait = [t_glitch[i] - t_glitch[i - 1] for i in range(1, len(t_glitch))]

    # Remove first glitch for uniformity
    if len(t_glitch) > 1:
        t_glitch = t_glitch[1:]
        t_rise = t_rise[1:]
        del_omega = del_omega[1:]

    # Stats
    if del_omega:
        mean = sum(del_omega) / len(del_omega)
        median = np.median(del_omega)
        max_val = max(del_omega)
        min_val = min(del_omega)
    else:
        mean = median = max_val = min_val = 0

    # Write info
    with open(os.path.join(pathplace, "info_glitch.dat"), "a") as f:
        f.write(f"Smallest allowed glitch size = {epsilon} omega_0\n")
        f.write(f"{len(t_glitch)} glitches found\n")
        f.write(f"Biggest glitch size = {max_val:.5e} omega_0\n")
        f.write(f"Smallest glitch size = {min_val:.5e} omega_0\n")
        f.write(f"Mean glitch size = {mean:.5e} omega_0\n")
        f.write(f"Median glitch size = {median:.5e} omega_0\n")

    with open(os.path.join(pathplace, "data_glitch.dat"), "a") as f:
        f.write("t_glitch\tt_rise\tglitch_size\tt_wait\n")
        for i in range(len(t_glitch)):
            wait = t_wait[i] if i < len(t_wait) else 0
            f.write(f"{t_glitch[i]:.15f}\t{t_rise[i]:.15f}\t{del_omega[i]:.15f}\t{wait:.15f}\n")

# %%
# Apply float32 to arrays where safe (output arrays, pinning grid)
V_0 = np.zeros((nmax, nmax), dtype=np.float32)
V_0_original = np.zeros((nmax, nmax), dtype=np.float32)
omega_c_vec = np.zeros(int(runtime_simulation / del_t), dtype=np.float32).tolist()
omega_s_vec = np.zeros_like(omega_c_vec).tolist()
tvalues = []
vortex_states = []  # Will store float32 state vectors if needed

# %%
pip install numba
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numba in /raid5/homes/owilson/.local/lib/python3.8/site-packages (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /raid5/homes/owilson/.local/lib/python3.8/site-packages (from numba) (0.41.1)
# Requirement already satisfied: numpy<1.27,>=1.22 in /raid5/homes/owilson/.local/lib/python3.8/site-packages (from numba) (1.22.4)
# Requirement already satisfied: importlib-metadata in /raid5/homes/owilson/.local/lib/python3.8/site-packages (from numba) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /raid5/homes/owilson/.local/lib/python3.8/site-packages (from importlib-metadata->numba) (3.20.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from numba import njit, prange
import numpy as np

@njit(parallel=True)
def fast_interaction_loop(f_local, nv, K, K_img, imgvortex_vectx, imgvortex_vecty,
                          omega_c, phi, V_0, Xi, a, R, nmax):
    dfdt = np.zeros(2 * nv, dtype=np.float64)

    for i in prange(nv):
        xi = f_local[i]
        yi = f_local[i + nv]
        Ki = K[i]
        if Ki == 0:
            continue
        dxdt = omega_c * yi
        dydt = -omega_c * xi

        for j in range(nv):
            if i == j or K[j] == 0:
                continue
            xj = f_local[j]
            yj = f_local[j + nv]
            dx = xi - xj
            dy = yi - yj
            r2 = dx * dx + dy * dy
            dxdt += -K[j] * Ki * dy / r2
            dydt += K[j] * Ki * dx / r2

            dx_img = xi - imgvortex_vectx[j]
            dy_img = yi - imgvortex_vecty[j]
            r2_img = dx_img * dx_img + dy_img * dy_img
            dxdt += K_img[j] * Ki * dy_img / r2_img
            dydt += -K_img[j] * Ki * dx_img / r2_img

        nx = int(round((xi + R) / a))
        ny = int(round((yi + R) / a))
        if nx <= 0 or ny <= 0 or nx >= nmax or ny >= nmax:
            nx, ny = 0, 0

        x_pin = -R + round((xi + R) / a) * a
        y_pin = -R + round((yi + R) / a) * a
        r2_pin = (x_pin - xi)**2 + (y_pin - yi)**2
        force_factor = V_0[nx, ny] * np.exp(-r2_pin / (2 * Xi**2))
        dxdt += force_factor * (yi - y_pin)
        dydt += -force_factor * (xi - x_pin)

        vel_x = dxdt * Ki
        vel_y = dydt * Ki
        dfdt[i] = np.cos(phi) * vel_x + np.sin(phi) * vel_y
        dfdt[i + nv] = -np.sin(phi) * vel_x + np.cos(phi) * vel_y

    return dfdt

# %%
# Replace eom_wrapper to call the Numba-accelerated function
def eom_wrapper(t, f_local):
    return fast_interaction_loop(
        np.asarray(f_local, dtype=np.float64),
        nv,
        np.asarray(K, dtype=np.float64),
        np.asarray(K_img, dtype=np.float64),
        np.asarray(imgvortex_vectx, dtype=np.float64),
        np.asarray(imgvortex_vecty, dtype=np.float64),
        omega_c,
        phi,
        np.asarray(V_0, dtype=np.float64),
        Xi,
        a,
        R,
        nmax
    )

# %%
from multiprocessing import Pool, freeze_support

def run_single_sim(run_id_arg):
    global run_id
    run_id = run_id_arg
    reinitialize()
    create_output_files(run_id)
    vortexinit1()
    initial_state()
    circulation_init()
    vortex_counter()
    pin_config_set()
    pins_count()
    write_info_start()
    stabilization()
    write_data_post_stabilization()
    global t, tvalues, prog
    t = 0
    tvalues.clear()
    prog = 0
    trig_init()
    vortex_counter()
    kiss_fix()
    write_info_mid()
    simulation()
    write_info_end()
    write_data_post_simulation()
    find_glitch(omega_c_vec, tvalues, epsilon_glitch)

if __name__ == "__main__":
    freeze_support()  # Needed for Windows
    os.makedirs(path, exist_ok=True)
    with Pool(processes=4) as pool:  # Adjust number of cores here
        pool.map(run_single_sim, list(range(1, numb_runs + 1)))
# Out:
# Stabilization progress: 0.015915494309189534% complete
# Stabilization progress: 0.015915494309189534% complete
# Stabilization progress: 0.015915494309189534% complete
# Stabilization progress: 0.03183098861837907% complete
# Stabilization progress: 0.03183098861837907% complete
# Stabilization progress: 0.015915494309189534% complete
# Stabilization progress: 0.03183098861837907% complete
# Stabilization progress: 0.047746482927568605% complete
# Stabilization progress: 0.047746482927568605% complete
# Stabilization progress: 0.03183098861837907% complete
# Stabilization progress: 0.047746482927568605% complete
# Stabilization progress: 0.06366197723675814% complete
# Stabilization progress: 0.06366197723675814% complete
# Stabilization progress: 0.047746482927568605% complete
# Stabilization progress: 0.06366197723675814% complete
# Stabilization progress: 0.07957747154594767% complete
# Stabilization progress: 0.07957747154594767% complete
# Stabilization progress: 0.06366197723675814% complete
# Stabilization progress: 0.07957747154594767% complete
# Stabilization progress: 0.07957747154594767% complete
# Stabilization progress: 0.09549296585513721% complete
# Stabilization progress: 0.09549296585513721% complete
# Stabilization progress: 0.09549296585513721% complete
# Stabilization progress: 0.09549296585513721% complete
# Stabilization progress: 0.11140846016432675% complete
# Stabilization progress: 0.11140846016432675% complete
# Stabilization progress: 0.11140846016432675% complete
# Stabilization progress: 0.11140846016432675% complete
# Stabilization progress: 0.12732395447351627% complete
# Stabilization progress: 0.12732395447351627% complete
# Stabilization progress: 0.12732395447351627% complete
# Stabilization progress: 0.12732395447351627% complete
# Stabilization progress: 0.1432394487827058% complete
# Stabilization progress: 0.1432394487827058% complete
# Stabilization progress: 0.1432394487827058% complete
# Stabilization progress: 0.1432394487827058% complete
# Stabilization progress: 0.15915494309189535% complete
# Stabilization progress: 0.15915494309189535% complete
# Stabilization progress: 0.15915494309189535% complete
# Stabilization progress: 0.15915494309189535% complete
# Stabilization progress: 0.17507043740108486% complete
# Stabilization progress: 0.17507043740108486% complete
# Stabilization progress: 0.17507043740108486% complete
# Stabilization progress: 0.17507043740108486% complete
# Stabilization progress: 0.1909859317102744% complete
# Stabilization progress: 0.1909859317102744% complete
# Stabilization progress: 0.1909859317102744% complete
# Stabilization progress: 0.1909859317102744% complete
# Stabilization progress: 0.2069014260194639% complete
# Stabilization progress: 0.2069014260194639% complete
# Stabilization progress: 0.2069014260194639% complete
# Stabilization progress: 0.2069014260194639% complete
# Stabilization progress: 0.22281692032865347% complete
# Stabilization progress: 0.22281692032865347% complete
# Stabilization progress: 0.22281692032865347% complete
# Stabilization progress: 0.22281692032865347% complete
# Stabilization progress: 0.238732414637843% complete
# Stabilization progress: 0.238732414637843% complete
# Stabilization progress: 0.238732414637843% complete
# Stabilization progress: 0.238732414637843% complete
# Stabilization progress: 0.25464790894703254% complete
# Stabilization progress: 0.25464790894703254% complete
# Stabilization progress: 0.25464790894703254% complete
# Stabilization progress: 0.25464790894703254% complete
# Stabilization progress: 0.2705634032562221% complete
# Stabilization progress: 0.2705634032562221% complete
# Stabilization progress: 0.2705634032562221% complete
# Stabilization progress: 0.2705634032562221% complete
# Stabilization progress: 0.28647889756541167% complete
# Stabilization progress: 0.28647889756541167% complete
# Stabilization progress: 0.28647889756541167% complete
# Stabilization progress: 0.28647889756541167% complete
# Stabilization progress: 0.3023943918746012% complete
# Stabilization progress: 0.3023943918746012% complete
# Stabilization progress: 0.3023943918746012% complete
# Stabilization progress: 0.3023943918746012% complete
# Stabilization progress: 0.31830988618379075% complete
# Stabilization progress: 0.31830988618379075% complete
# Stabilization progress: 0.31830988618379075% complete
# Stabilization progress: 0.31830988618379075% complete
# Stabilization progress: 0.3342253804929803% complete
# Stabilization progress: 0.3342253804929803% complete
# Stabilization progress: 0.3342253804929803% complete
# Stabilization progress: 0.3342253804929803% complete
# Stabilization progress: 0.3501408748021699% complete
# Stabilization progress: 0.3501408748021699% complete
# Stabilization progress: 0.3501408748021699% complete
# Stabilization progress: 0.3501408748021699% complete
# Stabilization progress: 0.36605636911135936% complete
# Stabilization progress: 0.36605636911135936% complete
# Stabilization progress: 0.36605636911135936% complete
# Stabilization progress: 0.36605636911135936% complete
# Stabilization progress: 0.38197186342054895% complete
# Stabilization progress: 0.38197186342054895% complete
# Stabilization progress: 0.38197186342054895% complete
# Stabilization progress: 0.38197186342054895% complete
# Stabilization progress: 0.39788735772973843% complete
# Stabilization progress: 0.39788735772973843% complete
# Stabilization progress: 0.39788735772973843% complete
# Stabilization progress: 0.39788735772973843% complete
# Stabilization progress: 0.41380285203892797% complete
# Stabilization progress: 0.41380285203892797% complete
# Stabilization progress: 0.41380285203892797% complete
# Stabilization progress: 0.41380285203892797% complete
# Stabilization progress: 0.42971834634811756% complete
# Stabilization progress: 0.42971834634811756% complete
# Stabilization progress: 0.42971834634811756% complete
# Stabilization progress: 0.4456338406573071% complete
# Stabilization progress: 0.42971834634811756% complete
# Stabilization progress: 0.4456338406573071% complete
# Stabilization progress: 0.4456338406573071% complete
# Stabilization progress: 0.4456338406573071% complete
# Stabilization progress: 0.46154933496649664% complete
# Stabilization progress: 0.46154933496649664% complete
# Stabilization progress: 0.46154933496649664% complete
# Stabilization progress: 0.46154933496649664% complete
# Stabilization progress: 0.4774648292756862% complete
# Stabilization progress: 0.4774648292756862% complete
# Stabilization progress: 0.4774648292756862% complete
# Stabilization progress: 0.4774648292756862% complete
# Stabilization progress: 0.49338032358487577% complete
# Stabilization progress: 0.49338032358487577% complete
# Stabilization progress: 0.49338032358487577% complete
# Stabilization progress: 0.5092958178940653% complete
# Stabilization progress: 0.49338032358487577% complete
# Stabilization progress: 0.5092958178940653% complete
# Stabilization progress: 0.5092958178940653% complete
# Stabilization progress: 0.5252113122032548% complete
# Stabilization progress: 0.5252113122032548% complete
# Stabilization progress: 0.5092958178940653% complete
# Stabilization progress: 0.5252113122032548% complete
# Stabilization progress: 0.5411268065124444% complete
# Stabilization progress: 0.5411268065124444% complete
# Stabilization progress: 0.5252113122032548% complete
# Stabilization progress: 0.5411268065124444% complete
# Stabilization progress: 0.557042300821634% complete
# Stabilization progress: 0.5411268065124444% complete
# Stabilization progress: 0.557042300821634% complete
# Stabilization progress: 0.557042300821634% complete
# Stabilization progress: 0.5729577951308235% complete
# Stabilization progress: 0.557042300821634% complete
# Stabilization progress: 0.5729577951308235% complete
# Stabilization progress: 0.5729577951308235% complete
# Stabilization progress: 0.588873289440013% complete
# Stabilization progress: 0.5729577951308235% complete
# Stabilization progress: 0.588873289440013% complete
# Stabilization progress: 0.588873289440013% complete
# Stabilization progress: 0.6047887837492025% complete
# Stabilization progress: 0.588873289440013% complete
# Stabilization progress: 0.6047887837492025% complete
# Stabilization progress: 0.6047887837492025% complete
# Stabilization progress: 0.6207042780583921% complete
# Stabilization progress: 0.6047887837492025% complete
# Stabilization progress: 0.6207042780583921% complete
# Stabilization progress: 0.6207042780583921% complete
# Stabilization progress: 0.6366197723675817% complete
# Stabilization progress: 0.6207042780583921% complete
# Stabilization progress: 0.6366197723675817% complete
# Stabilization progress: 0.6366197723675817% complete
# Stabilization progress: 0.6525352666767712% complete
# Stabilization progress: 0.6366197723675817% complete
# Stabilization progress: 0.6525352666767712% complete
# Stabilization progress: 0.6684507609859608% complete
# Stabilization progress: 0.6525352666767712% complete
# Stabilization progress: 0.6525352666767712% complete
# Stabilization progress: 0.6684507609859608% complete
# Stabilization progress: 0.6843662552951504% complete
# Stabilization progress: 0.6684507609859608% complete
# Stabilization progress: 0.6684507609859608% complete
# Stabilization progress: 0.6843662552951504% complete
# Stabilization progress: 0.7002817496043399% complete
# Stabilization progress: 0.6843662552951504% complete
# Stabilization progress: 0.6843662552951504% complete
# Stabilization progress: 0.7002817496043399% complete
# Stabilization progress: 0.7161972439135295% complete
# Stabilization progress: 0.7002817496043399% complete
# Stabilization progress: 0.7002817496043399% complete
# Stabilization progress: 0.7161972439135295% complete
# Stabilization progress: 0.7321127382227189% complete
# Stabilization progress: 0.7161972439135295% complete
# Stabilization progress: 0.7161972439135295% complete
# Stabilization progress: 0.7480282325319085% complete
# Stabilization progress: 0.7321127382227189% complete
# Stabilization progress: 0.7321127382227189% complete
# Stabilization progress: 0.7321127382227189% complete
# Stabilization progress: 0.7480282325319085% complete
# Stabilization progress: 0.7639437268410981% complete
# Stabilization progress: 0.7480282325319085% complete
# Stabilization progress: 0.7480282325319085% complete
# Stabilization progress: 0.7639437268410981% complete
# Stabilization progress: 0.7798592211502876% complete
# Stabilization progress: 0.7639437268410981% complete
# Stabilization progress: 0.7639437268410981% complete
# Stabilization progress: 0.7798592211502876% complete
# Stabilization progress: 0.7957747154594771% complete
# Stabilization progress: 0.7798592211502876% complete
# Stabilization progress: 0.7798592211502876% complete
# Stabilization progress: 0.7957747154594771% complete
# Stabilization progress: 0.7957747154594771% complete
# Stabilization progress: 0.8116902097686667% complete
# Stabilization progress: 0.7957747154594771% complete
# Stabilization progress: 0.8116902097686667% complete
# Stabilization progress: 0.827605704077856% complete
# Stabilization progress: 0.8116902097686667% complete
# Stabilization progress: 0.8116902097686667% complete
# Stabilization progress: 0.827605704077856% complete
# Stabilization progress: 0.8435211983870458% complete
# Stabilization progress: 0.827605704077856% complete
# Stabilization progress: 0.827605704077856% complete
# Stabilization progress: 0.8594366926962353% complete
# Stabilization progress: 0.8435211983870458% complete
# Stabilization progress: 0.8435211983870458% complete
# Stabilization progress: 0.8435211983870458% complete
# Stabilization progress: 0.8753521870054247% complete
# Stabilization progress: 0.8594366926962353% complete
# Stabilization progress: 0.8594366926962353% complete
# Stabilization progress: 0.8594366926962353% complete
# Stabilization progress: 0.8912676813146144% complete
# Stabilization progress: 0.8753521870054247% complete
# Stabilization progress: 0.8753521870054247% complete
# Stabilization progress: 0.9071831756238038% complete
# Stabilization progress: 0.8753521870054247% complete
# Stabilization progress: 0.8912676813146144% complete
# Stabilization progress: 0.8912676813146144% complete
# Stabilization progress: 0.9230986699329934% complete
# Stabilization progress: 0.8912676813146144% complete
# Stabilization progress: 0.9071831756238038% complete
# Stabilization progress: 0.9390141642421831% complete
# Stabilization progress: 0.9071831756238038% complete
# Stabilization progress: 0.9230986699329934% complete
# Stabilization progress: 0.9071831756238038% complete
# Stabilization progress: 0.9549296585513725% complete
# Stabilization progress: 0.9230986699329934% complete
# Stabilization progress: 0.9390141642421831% complete
# Stabilization progress: 0.9230986699329934% complete
# Stabilization progress: 0.970845152860562% complete
# Stabilization progress: 0.9390141642421831% complete
# Stabilization progress: 0.9549296585513725% complete
# Stabilization progress: 0.9390141642421831% complete
# Stabilization progress: 0.9867606471697518% complete
# Stabilization progress: 0.9549296585513725% complete
# Stabilization progress: 0.970845152860562% complete
# Stabilization progress: 0.9549296585513725% complete
# Stabilization progress: 1.0026761414789411% complete
# Stabilization progress: 0.970845152860562% complete
# Stabilization progress: 0.9867606471697518% complete
# Stabilization progress: 0.970845152860562% complete
# Stabilization progress: 1.0185916357881308% complete
# Stabilization progress: 0.9867606471697518% complete
# Stabilization progress: 1.0026761414789411% complete
# Stabilization progress: 1.0026761414789411% complete
# Stabilization progress: 0.9867606471697518% complete
# Stabilization progress: 1.03450713009732% complete
# Stabilization progress: 1.0185916357881308% complete
# Stabilization progress: 1.0026761414789411% complete
# Stabilization progress: 1.0504226244065098% complete
# Stabilization progress: 1.0185916357881308% complete
# Stabilization progress: 1.03450713009732% complete
# Stabilization progress: 1.0185916357881308% complete
# Stabilization progress: 1.03450713009732% complete
# Stabilization progress: 1.0663381187156995% complete
# Stabilization progress: 1.0504226244065098% complete
# Stabilization progress: 1.03450713009732% complete
# Stabilization progress: 1.0504226244065098% complete
# Stabilization progress: 1.0663381187156995% complete
# Stabilization progress: 1.0822536130248888% complete
# Stabilization progress: 1.0663381187156995% complete
# Stabilization progress: 1.0822536130248888% complete
# Stabilization progress: 1.0504226244065098% complete
# Stabilization progress: 1.0981691073340785% complete
# Stabilization progress: 1.0981691073340785% complete
# Stabilization progress: 1.0822536130248888% complete
# Stabilization progress: 1.0663381187156995% complete
# Stabilization progress: 1.1140846016432682% complete
# Stabilization progress: 1.1140846016432682% complete
# Stabilization progress: 1.0981691073340785% complete
# Stabilization progress: 1.0822536130248888% complete
# Stabilization progress: 1.1300000959524574% complete
# Stabilization progress: 1.1300000959524574% complete
# Stabilization progress: 1.1140846016432682% complete
# Stabilization progress: 1.0981691073340785% complete
# Stabilization progress: 1.1459155902616471% complete
# Stabilization progress: 1.1459155902616471% complete
# Stabilization progress: 1.1300000959524574% complete
# Stabilization progress: 1.1140846016432682% complete
# Stabilization progress: 1.1618310845708366% complete
# Stabilization progress: 1.1618310845708366% complete
# Stabilization progress: 1.1459155902616471% complete
# Stabilization progress: 1.1300000959524574% complete
# Stabilization progress: 1.177746578880026% complete
# Stabilization progress: 1.177746578880026% complete
# Stabilization progress: 1.1618310845708366% complete
# Stabilization progress: 1.1459155902616471% complete
# Stabilization progress: 1.1936620731892158% complete
# Stabilization progress: 1.1936620731892158% complete
# Stabilization progress: 1.177746578880026% complete
# Stabilization progress: 1.1618310845708366% complete
# Stabilization progress: 1.2095775674984053% complete
# Stabilization progress: 1.1936620731892158% complete
# Stabilization progress: 1.2095775674984053% complete
# Stabilization progress: 1.177746578880026% complete
# Stabilization progress: 1.2095775674984053% complete
# Stabilization progress: 1.2254930618075948% complete
# Stabilization progress: 1.2254930618075948% complete
# Stabilization progress: 1.1936620731892158% complete
# Stabilization progress: 1.2254930618075948% complete
# Stabilization progress: 1.2414085561167845% complete
# Stabilization progress: 1.2095775674984053% complete
# Stabilization progress: 1.2414085561167845% complete
# Stabilization progress: 1.257324050425974% complete
# Stabilization progress: 1.2414085561167845% complete
# Stabilization progress: 1.2254930618075948% complete
# Stabilization progress: 1.257324050425974% complete
# Stabilization progress: 1.257324050425974% complete
# Stabilization progress: 1.2732395447351634% complete
# Stabilization progress: 1.2732395447351634% complete
# Stabilization progress: 1.2414085561167845% complete
# Stabilization progress: 1.2732395447351634% complete
# Stabilization progress: 1.289155039044353% complete
# Stabilization progress: 1.257324050425974% complete
# Stabilization progress: 1.289155039044353% complete
# Stabilization progress: 1.289155039044353% complete
# Stabilization progress: 1.3050705333535426% complete
# Stabilization progress: 1.3050705333535426% complete
# Stabilization progress: 1.2732395447351634% complete
# Stabilization progress: 1.3050705333535426% complete
# Stabilization progress: 1.289155039044353% complete
# Stabilization progress: 1.320986027662732% complete
# Stabilization progress: 1.320986027662732% complete
# Stabilization progress: 1.320986027662732% complete
# Stabilization progress: 1.3369015219719216% complete
# Stabilization progress: 1.3050705333535426% complete
# Stabilization progress: 1.3369015219719216% complete
# Stabilization progress: 1.3369015219719216% complete
# Stabilization progress: 1.320986027662732% complete
# Stabilization progress: 1.3528170162811113% complete
# Stabilization progress: 1.3528170162811113% complete
# Stabilization progress: 1.3528170162811113% complete
# Stabilization progress: 1.3369015219719216% complete
# Stabilization progress: 1.3687325105903008% complete
# Stabilization progress: 1.3687325105903008% complete
# Stabilization progress: 1.3687325105903008% complete
# Stabilization progress: 1.3846480048994902% complete
# Stabilization progress: 1.3528170162811113% complete
# Stabilization progress: 1.3846480048994902% complete
# Stabilization progress: 1.3846480048994902% complete
# Stabilization progress: 1.40056349920868% complete
# Stabilization progress: 1.3687325105903008% complete
# Stabilization progress: 1.40056349920868% complete
# Stabilization progress: 1.40056349920868% complete
# Stabilization progress: 1.4164789935178694% complete
# Stabilization progress: 1.4164789935178694% complete
# Stabilization progress: 1.3846480048994902% complete
# Stabilization progress: 1.4164789935178694% complete
# Stabilization progress: 1.432394487827059% complete
# Stabilization progress: 1.432394487827059% complete
# Stabilization progress: 1.4483099821362486% complete
# Stabilization progress: 1.40056349920868% complete
# Stabilization progress: 1.432394487827059% complete
# Stabilization progress: 1.4483099821362486% complete
# Stabilization progress: 1.464225476445438% complete
# Stabilization progress: 1.4483099821362486% complete
# Stabilization progress: 1.4164789935178694% complete
# Stabilization progress: 1.464225476445438% complete
# Stabilization progress: 1.4801409707546276% complete
# Stabilization progress: 1.464225476445438% complete
# Stabilization progress: 1.432394487827059% complete
# Stabilization progress: 1.4801409707546276% complete
# Stabilization progress: 1.4960564650638173% complete
# Stabilization progress: 1.4801409707546276% complete
# Stabilization progress: 1.4483099821362486% complete
# Stabilization progress: 1.4960564650638173% complete
# Stabilization progress: 1.5119719593730068% complete
# Stabilization progress: 1.464225476445438% complete
# Stabilization progress: 1.4960564650638173% complete
# Stabilization progress: 1.5119719593730068% complete
# Stabilization progress: 1.5278874536821963% complete
# Stabilization progress: 1.4801409707546276% complete
# Stabilization progress: 1.5119719593730068% complete
# Stabilization progress: 1.5278874536821963% complete
# Stabilization progress: 1.5438029479913857% complete
# Stabilization progress: 1.4960564650638173% complete
# Stabilization progress: 1.5278874536821963% complete
# Stabilization progress: 1.5438029479913857% complete
# Stabilization progress: 1.5597184423005754% complete
# Stabilization progress: 1.5119719593730068% complete
# Stabilization progress: 1.5438029479913857% complete
# Stabilization progress: 1.575633936609765% complete
# Stabilization progress: 1.5597184423005754% complete
# Stabilization progress: 1.5278874536821963% complete
# Stabilization progress: 1.5597184423005754% complete
# Stabilization progress: 1.5915494309189544% complete
# Stabilization progress: 1.5438029479913857% complete
# Stabilization progress: 1.575633936609765% complete
# Stabilization progress: 1.575633936609765% complete
# Stabilization progress: 1.6074649252281439% complete
# Stabilization progress: 1.5915494309189544% complete
# Stabilization progress: 1.5597184423005754% complete
# Stabilization progress: 1.5915494309189544% complete
# Stabilization progress: 1.6233804195373336% complete
# Stabilization progress: 1.6074649252281439% complete
# Stabilization progress: 1.6074649252281439% complete
# Stabilization progress: 1.639295913846523% complete
# Stabilization progress: 1.575633936609765% complete
# Stabilization progress: 1.6233804195373336% complete
# Stabilization progress: 1.6552114081557125% complete
# Stabilization progress: 1.6233804195373336% complete
# Stabilization progress: 1.5915494309189544% complete
# Stabilization progress: 1.639295913846523% complete
# Stabilization progress: 1.6711269024649023% complete
# Stabilization progress: 1.639295913846523% complete
# Stabilization progress: 1.6552114081557125% complete
# Stabilization progress: 1.6074649252281439% complete
# Stabilization progress: 1.6870423967740917% complete
# Stabilization progress: 1.6552114081557125% complete
# Stabilization progress: 1.6233804195373336% complete
# Stabilization progress: 1.6711269024649023% complete
# Stabilization progress: 1.7029578910832812% complete
# Stabilization progress: 1.6711269024649023% complete
# Stabilization progress: 1.639295913846523% complete
# Stabilization progress: 1.6870423967740917% complete
# Stabilization progress: 1.718873385392471% complete
# Stabilization progress: 1.6870423967740917% complete
# Stabilization progress: 1.6552114081557125% complete
# Stabilization progress: 1.7347888797016604% complete
# Stabilization progress: 1.7029578910832812% complete
# Stabilization progress: 1.7029578910832812% complete
# Stabilization progress: 1.6711269024649023% complete
# Stabilization progress: 1.7507043740108499% complete
# Stabilization progress: 1.718873385392471% complete
# Stabilization progress: 1.718873385392471% complete
# Stabilization progress: 1.6870423967740917% complete
# Stabilization progress: 1.7666198683200396% complete
# Stabilization progress: 1.7347888797016604% complete
# Stabilization progress: 1.7029578910832812% complete
# Stabilization progress: 1.782535362629229% complete
# Stabilization progress: 1.7347888797016604% complete
# Stabilization progress: 1.7507043740108499% complete
# Stabilization progress: 1.718873385392471% complete
# Stabilization progress: 1.7984508569384186% complete
# Stabilization progress: 1.7507043740108499% complete
# Stabilization progress: 1.7666198683200396% complete
# Stabilization progress: 1.7347888797016604% complete
# Stabilization progress: 1.8143663512476083% complete
# Stabilization progress: 1.782535362629229% complete
# Stabilization progress: 1.7666198683200396% complete
# Stabilization progress: 1.7507043740108499% complete
# Stabilization progress: 1.8302818455567977% complete
# Stabilization progress: 1.7984508569384186% complete
# Stabilization progress: 1.782535362629229% complete
# Stabilization progress: 1.7666198683200396% complete
# Stabilization progress: 1.8461973398659872% complete
# Stabilization progress: 1.7984508569384186% complete
# Stabilization progress: 1.8143663512476083% complete
# Stabilization progress: 1.782535362629229% complete
# Stabilization progress: 1.8143663512476083% complete
# Stabilization progress: 1.8621128341751767% complete
# Stabilization progress: 1.8302818455567977% complete
# Stabilization progress: 1.7984508569384186% complete
# Stabilization progress: 1.8302818455567977% complete
# Stabilization progress: 1.8461973398659872% complete
# Stabilization progress: 1.8780283284843664% complete
# Stabilization progress: 1.8143663512476083% complete
# Stabilization progress: 1.8461973398659872% complete
# Stabilization progress: 1.8939438227935559% complete
# Stabilization progress: 1.8621128341751767% complete
# Stabilization progress: 1.8302818455567977% complete
# Stabilization progress: 1.8621128341751767% complete
# Stabilization progress: 1.8780283284843664% complete
# Stabilization progress: 1.8461973398659872% complete
# Stabilization progress: 1.9098593171027454% complete
# Stabilization progress: 1.8780283284843664% complete
# Stabilization progress: 1.8621128341751767% complete
# Stabilization progress: 1.8939438227935559% complete
# Stabilization progress: 1.925774811411935% complete
# Stabilization progress: 1.8939438227935559% complete
# Stabilization progress: 1.9098593171027454% complete
# Stabilization progress: 1.8780283284843664% complete
# Stabilization progress: 1.9098593171027454% complete
# Stabilization progress: 1.9416903057211246% complete
# Stabilization progress: 1.925774811411935% complete
# Stabilization progress: 1.8939438227935559% complete
# Stabilization progress: 1.925774811411935% complete
# Stabilization progress: 1.957605800030314% complete
# Stabilization progress: 1.9416903057211246% complete
# Stabilization progress: 1.9098593171027454% complete
# Stabilization progress: 1.9735212943395037% complete
# Stabilization progress: 1.9416903057211246% complete
# Stabilization progress: 1.957605800030314% complete
# Stabilization progress: 1.925774811411935% complete
# Stabilization progress: 1.9894367886486932% complete
# Stabilization progress: 1.9735212943395037% complete
# Stabilization progress: 1.9416903057211246% complete
# Stabilization progress: 1.957605800030314% complete
# Stabilization progress: 2.0053522829578827% complete
# Stabilization progress: 1.9894367886486932% complete
# Stabilization progress: 1.957605800030314% complete
# Stabilization progress: 2.0212677772670724% complete
# Stabilization progress: 1.9735212943395037% complete
# Stabilization progress: 2.0053522829578827% complete
# Stabilization progress: 1.9735212943395037% complete
# Stabilization progress: 2.0371832715762617% complete
# Stabilization progress: 1.9894367886486932% complete
# Stabilization progress: 2.0212677772670724% complete
# Stabilization progress: 1.9894367886486932% complete
# Stabilization progress: 2.0530987658854514% complete
# Stabilization progress: 2.0053522829578827% complete
# Stabilization progress: 2.0371832715762617% complete
# Stabilization progress: 2.0053522829578827% complete
# Stabilization progress: 2.069014260194641% complete
# Stabilization progress: 2.0212677772670724% complete
# Stabilization progress: 2.0530987658854514% complete
# Stabilization progress: 2.0212677772670724% complete
# Stabilization progress: 2.0849297545038303% complete
# Stabilization progress: 2.069014260194641% complete
# Stabilization progress: 2.0371832715762617% complete
# Stabilization progress: 2.10084524881302% complete
# Stabilization progress: 2.0371832715762617% complete
# Stabilization progress: 2.0849297545038303% complete
# Stabilization progress: 2.0530987658854514% complete
# Stabilization progress: 2.1167607431222093% complete
# Stabilization progress: 2.0530987658854514% complete
# Stabilization progress: 2.10084524881302% complete
# Stabilization progress: 2.069014260194641% complete
# Stabilization progress: 2.132676237431399% complete
# Stabilization progress: 2.069014260194641% complete
# Stabilization progress: 2.1167607431222093% complete
# Stabilization progress: 2.0849297545038303% complete
# Stabilization progress: 2.1485917317405887% complete
# Stabilization progress: 2.0849297545038303% complete
# Stabilization progress: 2.132676237431399% complete
# Stabilization progress: 2.10084524881302% complete
# Stabilization progress: 2.164507226049778% complete
# Stabilization progress: 2.10084524881302% complete
# Stabilization progress: 2.1485917317405887% complete
# Stabilization progress: 2.1167607431222093% complete
# Stabilization progress: 2.1167607431222093% complete
# Stabilization progress: 2.1804227203589677% complete
# Stabilization progress: 2.164507226049778% complete
# Stabilization progress: 2.1963382146681574% complete
# Stabilization progress: 2.132676237431399% complete
# Stabilization progress: 2.132676237431399% complete
# Stabilization progress: 2.2122537089773466% complete
# Stabilization progress: 2.1485917317405887% complete
# Stabilization progress: 2.1485917317405887% complete
# Stabilization progress: 2.1804227203589677% complete
# Stabilization progress: 2.2281692032865363% complete
# Stabilization progress: 2.164507226049778% complete
# Stabilization progress: 2.164507226049778% complete
# Stabilization progress: 2.1963382146681574% complete
# Stabilization progress: 2.244084697595726% complete
# Stabilization progress: 2.1804227203589677% complete
# Stabilization progress: 2.1804227203589677% complete
# Stabilization progress: 2.2600001919049153% complete
# Stabilization progress: 2.2122537089773466% complete
# Stabilization progress: 2.1963382146681574% complete
# Stabilization progress: 2.1963382146681574% complete
# Stabilization progress: 2.275915686214105% complete
# Stabilization progress: 2.2281692032865363% complete
# Stabilization progress: 2.2122537089773466% complete
# Stabilization progress: 2.2122537089773466% complete
# Stabilization progress: 2.2918311805232947% complete
# Stabilization progress: 2.2281692032865363% complete
# Stabilization progress: 2.244084697595726% complete
# Stabilization progress: 2.307746674832484% complete
# Stabilization progress: 2.2281692032865363% complete
# Stabilization progress: 2.244084697595726% complete
# Stabilization progress: 2.2600001919049153% complete
# Stabilization progress: 2.3236621691416737% complete
# Stabilization progress: 2.244084697595726% complete
# Stabilization progress: 2.2600001919049153% complete
# Stabilization progress: 2.275915686214105% complete
# Stabilization progress: 2.275915686214105% complete
# Stabilization progress: 2.3395776634508634% complete
# Stabilization progress: 2.2600001919049153% complete
# Stabilization progress: 2.2918311805232947% complete
# Stabilization progress: 2.3554931577600526% complete
# Stabilization progress: 2.2918311805232947% complete
# Stabilization progress: 2.275915686214105% complete
# Stabilization progress: 2.307746674832484% complete
# Stabilization progress: 2.3714086520692423% complete
# Stabilization progress: 2.307746674832484% complete
# Stabilization progress: 2.2918311805232947% complete
# Stabilization progress: 2.3236621691416737% complete
# Stabilization progress: 2.387324146378432% complete
# Stabilization progress: 2.307746674832484% complete
# Stabilization progress: 2.3236621691416737% complete
# Stabilization progress: 2.3395776634508634% complete
# Stabilization progress: 2.4032396406876213% complete
# Stabilization progress: 2.3236621691416737% complete
# Stabilization progress: 2.3395776634508634% complete
# Stabilization progress: 2.3554931577600526% complete
# Stabilization progress: 2.419155134996811% complete
# Stabilization progress: 2.3554931577600526% complete
# Stabilization progress: 2.3395776634508634% complete
# Stabilization progress: 2.3714086520692423% complete
# Stabilization progress: 2.4350706293060007% complete
# Stabilization progress: 2.3714086520692423% complete
# Stabilization progress: 2.387324146378432% complete
# Stabilization progress: 2.3554931577600526% complete
# Stabilization progress: 2.45098612361519% complete
# Stabilization progress: 2.4032396406876213% complete
# Stabilization progress: 2.387324146378432% complete
# Stabilization progress: 2.4669016179243797% complete
# Stabilization progress: 2.3714086520692423% complete
# Stabilization progress: 2.419155134996811% complete
# Stabilization progress: 2.4032396406876213% complete
# Stabilization progress: 2.4828171122335694% complete
# Stabilization progress: 2.387324146378432% complete
# Stabilization progress: 2.4350706293060007% complete
# Stabilization progress: 2.419155134996811% complete
# Stabilization progress: 2.4032396406876213% complete
# Stabilization progress: 2.4987326065427586% complete
# Stabilization progress: 2.45098612361519% complete
# Stabilization progress: 2.4350706293060007% complete
# Stabilization progress: 2.419155134996811% complete
# Stabilization progress: 2.5146481008519483% complete
# Stabilization progress: 2.4669016179243797% complete
# Stabilization progress: 2.45098612361519% complete
# Stabilization progress: 2.4350706293060007% complete
# Stabilization progress: 2.530563595161138% complete
# Stabilization progress: 2.4828171122335694% complete
# Stabilization progress: 2.45098612361519% complete
# Stabilization progress: 2.5464790894703273% complete
# Stabilization progress: 2.4669016179243797% complete
# Stabilization progress: 2.4987326065427586% complete
# Stabilization progress: 2.4669016179243797% complete
# Stabilization progress: 2.4828171122335694% complete
# Stabilization progress: 2.562394583779517% complete
# Stabilization progress: 2.5146481008519483% complete
# Stabilization progress: 2.4828171122335694% complete
# Stabilization progress: 2.4987326065427586% complete
# Stabilization progress: 2.5783100780887063% complete
# Stabilization progress: 2.530563595161138% complete
# Stabilization progress: 2.4987326065427586% complete
# Stabilization progress: 2.594225572397896% complete
# Stabilization progress: 2.5146481008519483% complete
# Stabilization progress: 2.5464790894703273% complete
# Stabilization progress: 2.5146481008519483% complete
# Stabilization progress: 2.530563595161138% complete
# Stabilization progress: 2.6101410667070857% complete
# Stabilization progress: 2.562394583779517% complete
# Stabilization progress: 2.530563595161138% complete
# Stabilization progress: 2.5464790894703273% complete
# Stabilization progress: 2.626056561016275% complete
# Stabilization progress: 2.5783100780887063% complete
# Stabilization progress: 2.5464790894703273% complete
# Stabilization progress: 2.594225572397896% complete
# Stabilization progress: 2.6419720553254646% completeStabilization progress: 2.562394583779517% complete
#
# Stabilization progress: 2.562394583779517% complete
# Stabilization progress: 2.6578875496346543% complete
# Stabilization progress: 2.6101410667070857% complete
# Stabilization progress: 2.5783100780887063% complete
# Stabilization progress: 2.5783100780887063% complete
# Stabilization progress: 2.594225572397896% complete
# Stabilization progress: 2.6738030439438436% complete
# Stabilization progress: 2.626056561016275% complete
# Stabilization progress: 2.594225572397896% complete
# Stabilization progress: 2.6101410667070857% complete
# Stabilization progress: 2.6101410667070857% completeStabilization progress: 2.6419720553254646% complete
#
# Stabilization progress: 2.6897185382530333% complete
# Stabilization progress: 2.626056561016275% complete
# Stabilization progress: 2.705634032562223% complete
# Stabilization progress: 2.6578875496346543% complete
# Stabilization progress: 2.626056561016275% complete
# Stabilization progress: 2.6419720553254646% complete
# Stabilization progress: 2.7215495268714123% complete
# Stabilization progress: 2.6738030439438436% complete
# Stabilization progress: 2.6419720553254646% complete
# Stabilization progress: 2.6578875496346543% complete
# Stabilization progress: 2.737465021180602% complete
# Stabilization progress: 2.6897185382530333% complete
# Stabilization progress: 2.6578875496346543% complete
# Stabilization progress: 2.6738030439438436% complete
# Stabilization progress: 2.7533805154897917% complete
# Stabilization progress: 2.6738030439438436% complete
# Stabilization progress: 2.705634032562223% complete
# Stabilization progress: 2.6897185382530333% complete
# Stabilization progress: 2.7215495268714123% complete
# Stabilization progress: 2.769296009798981% complete
# Stabilization progress: 2.6897185382530333% complete
# Stabilization progress: 2.705634032562223% complete
# Stabilization progress: 2.737465021180602% complete
# Stabilization progress: 2.7852115041081706% complete
# Stabilization progress: 2.705634032562223% complete
# Stabilization progress: 2.7215495268714123% complete
# Stabilization progress: 2.7533805154897917% complete
# Stabilization progress: 2.7215495268714123% complete
# Stabilization progress: 2.8011269984173603% complete
# Stabilization progress: 2.737465021180602% complete
# Stabilization progress: 2.737465021180602% complete
# Stabilization progress: 2.769296009798981% complete
# Stabilization progress: 2.8170424927265496% complete
# Stabilization progress: 2.7533805154897917% complete
# Stabilization progress: 2.7852115041081706% complete
# Stabilization progress: 2.832957987035739% complete
# Stabilization progress: 2.7533805154897917% complete
# Stabilization progress: 2.769296009798981% complete
# Stabilization progress: 2.8011269984173603% complete
# Stabilization progress: 2.848873481344929% complete
# Stabilization progress: 2.769296009798981% complete
# Stabilization progress: 2.7852115041081706% complete
# Stabilization progress: 2.8170424927265496% complete
# Stabilization progress: 2.7852115041081706% complete
# Stabilization progress: 2.8647889756541183% complete
# Stabilization progress: 2.8011269984173603% complete
# Stabilization progress: 2.832957987035739% complete
# Stabilization progress: 2.8011269984173603% complete
# Stabilization progress: 2.880704469963308% complete
# Stabilization progress: 2.8170424927265496% complete
# Stabilization progress: 2.848873481344929% complete
# Stabilization progress: 2.832957987035739% complete
# Stabilization progress: 2.8966199642724977% complete
# Stabilization progress: 2.8170424927265496% complete
# Stabilization progress: 2.8647889756541183% complete
# Stabilization progress: 2.848873481344929% complete
# Stabilization progress: 2.912535458581687% complete
# Stabilization progress: 2.832957987035739% complete
# Stabilization progress: 2.880704469963308% complete
# Stabilization progress: 2.8647889756541183% complete
# Stabilization progress: 2.848873481344929% complete
# Stabilization progress: 2.928450952890876% complete
# Stabilization progress: 2.8966199642724977% complete
# Stabilization progress: 2.880704469963308% complete
# Stabilization progress: 2.8647889756541183% complete
# Stabilization progress: 2.9443664472000664% complete
# Stabilization progress: 2.912535458581687% complete
# Stabilization progress: 2.8966199642724977% complete
# Stabilization progress: 2.880704469963308% complete
# Stabilization progress: 2.9602819415092556% complete
# Stabilization progress: 2.928450952890876% complete
# Stabilization progress: 2.912535458581687% complete
# Stabilization progress: 2.8966199642724977% complete
# Stabilization progress: 2.9761974358184453% complete
# Stabilization progress: 2.9443664472000664% complete
# Stabilization progress: 2.928450952890876% complete
# Stabilization progress: 2.912535458581687% complete
# Stabilization progress: 2.992112930127635% complete
# Stabilization progress: 2.9602819415092556% complete
# Stabilization progress: 2.9443664472000664% complete
# Stabilization progress: 2.928450952890876% complete
# Stabilization progress: 2.9761974358184453% complete
# Stabilization progress: 3.0080284244368243% complete
# Stabilization progress: 2.9602819415092556% complete
# Stabilization progress: 2.9443664472000664% complete
# Stabilization progress: 2.992112930127635% complete
# Stabilization progress: 3.0239439187460135% complete
# Stabilization progress: 2.9761974358184453% complete
# Stabilization progress: 2.9602819415092556% complete
# Stabilization progress: 3.0080284244368243% complete
# Stabilization progress: 3.0398594130552037% complete
# Stabilization progress: 2.992112930127635% complete
# Stabilization progress: 2.9761974358184453% complete
# Stabilization progress: 3.0239439187460135% complete
# Stabilization progress: 3.0080284244368243% complete
# Stabilization progress: 3.055774907364393% complete
# Stabilization progress: 2.992112930127635% complete
# Stabilization progress: 3.0239439187460135% complete
# Stabilization progress: 3.0398594130552037% complete
# Stabilization progress: 3.0080284244368243% complete
# Stabilization progress: 3.0716904016735826% complete
# Stabilization progress: 3.0398594130552037% complete
# Stabilization progress: 3.055774907364393% complete
# Stabilization progress: 3.087605895982772% complete
# Stabilization progress: 3.0239439187460135% complete
# Stabilization progress: 3.055774907364393% complete
# Stabilization progress: 3.0716904016735826% complete
# Stabilization progress: 3.1035213902919616% complete
# Stabilization progress: 3.0398594130552037% complete
# Stabilization progress: 3.0716904016735826% complete
# Stabilization progress: 3.087605895982772% complete
# Stabilization progress: 3.055774907364393% complete
# Stabilization progress: 3.119436884601151% complete
# Stabilization progress: 3.087605895982772% complete
# Stabilization progress: 3.1035213902919616% complete
# Stabilization progress: 3.135352378910341% complete
# Stabilization progress: 3.0716904016735826% complete
# Stabilization progress: 3.1035213902919616% complete
# Stabilization progress: 3.119436884601151% complete
# Stabilization progress: 3.15126787321953% complete
# Stabilization progress: 3.087605895982772% complete
# Stabilization progress: 3.119436884601151% complete
# Stabilization progress: 3.135352378910341% complete
# Stabilization progress: 3.16718336752872% complete
# Stabilization progress: 3.135352378910341% complete
# Stabilization progress: 3.1035213902919616% complete
# Stabilization progress: 3.15126787321953% complete
# Stabilization progress: 3.183098861837909% complete
# Stabilization progress: 3.15126787321953% complete
# Stabilization progress: 3.119436884601151% complete
# Stabilization progress: 3.16718336752872% complete
# Stabilization progress: 3.199014356147098% complete
# Stabilization progress: 3.135352378910341% complete
# Stabilization progress: 3.16718336752872% complete
# Stabilization progress: 3.183098861837909% complete
# Stabilization progress: 3.183098861837909% complete
# Stabilization progress: 3.214929850456287% complete
# Stabilization progress: 3.15126787321953% complete
# Stabilization progress: 3.199014356147098% complete
# Stabilization progress: 3.230845344765477% complete
# Stabilization progress: 3.199014356147098% complete
# Stabilization progress: 3.16718336752872% complete
# Stabilization progress: 3.214929850456287% complete
# Stabilization progress: 3.246760839074666% complete
# Stabilization progress: 3.214929850456287% complete
# Stabilization progress: 3.183098861837909% complete
# Stabilization progress: 3.230845344765477% complete
# Stabilization progress: 3.230845344765477% complete
# Stabilization progress: 3.199014356147098% complete
# Stabilization progress: 3.262676333383855% complete
# Stabilization progress: 3.246760839074666% complete
# Stabilization progress: 3.278591827693044% complete
# Stabilization progress: 3.214929850456287% complete
# Stabilization progress: 3.246760839074666% complete
# Stabilization progress: 3.262676333383855% complete
# Stabilization progress: 3.294507322002233% complete
# Stabilization progress: 3.230845344765477% complete
# Stabilization progress: 3.262676333383855% complete
# Stabilization progress: 3.278591827693044% complete
# Stabilization progress: 3.246760839074666% complete
# Stabilization progress: 3.3104228163114224% complete
# Stabilization progress: 3.278591827693044% complete
# Stabilization progress: 3.294507322002233% complete
# Stabilization progress: 3.262676333383855% complete
# Stabilization progress: 3.294507322002233% complete
# Stabilization progress: 3.3263383106206112% complete
# Stabilization progress: 3.3104228163114224% complete
# Stabilization progress: 3.3104228163114224% complete
# Stabilization progress: 3.278591827693044% complete
# Stabilization progress: 3.3422538049298014% complete
# Stabilization progress: 3.3263383106206112% complete
# Stabilization progress: 3.3263383106206112% complete
# Stabilization progress: 3.294507322002233% complete
# Stabilization progress: 3.3422538049298014% complete
# Stabilization progress: 3.35816929923899% complete
# Stabilization progress: 3.3422538049298014% complete
# Stabilization progress: 3.3104228163114224% complete
# Stabilization progress: 3.35816929923899% complete
# Stabilization progress: 3.3740847935481795% complete
# Stabilization progress: 3.35816929923899% complete
# Stabilization progress: 3.3263383106206112% complete
# Stabilization progress: 3.3740847935481795% complete
# Stabilization progress: 3.3900002878573683% complete
# Stabilization progress: 3.3740847935481795% complete
# Stabilization progress: 3.3422538049298014% complete
# Stabilization progress: 3.3900002878573683% complete
# Stabilization progress: 3.4059157821665575% complete
# Stabilization progress: 3.3900002878573683% complete
# Stabilization progress: 3.35816929923899% complete
# Stabilization progress: 3.4059157821665575% complete
# Stabilization progress: 3.4059157821665575% complete
# Stabilization progress: 3.421831276475747% complete
# Stabilization progress: 3.3740847935481795% complete
# Stabilization progress: 3.421831276475747% complete
# Stabilization progress: 3.421831276475747% complete
# Stabilization progress: 3.4377467707849356% complete
# Stabilization progress: 3.3900002878573683% complete
# Stabilization progress: 3.4377467707849356% complete
# Stabilization progress: 3.4377467707849356% complete
# Stabilization progress: 3.4536622650941253% complete
# Stabilization progress: 3.4059157821665575% complete
# Stabilization progress: 3.4536622650941253% complete
# Stabilization progress: 3.4536622650941253% complete
# Stabilization progress: 3.4695777594033146% complete
# Stabilization progress: 3.421831276475747% complete
# Stabilization progress: 3.4695777594033146% complete
# Stabilization progress: 3.4695777594033146% complete
# Stabilization progress: 3.485493253712504% complete
# Stabilization progress: 3.4377467707849356% complete
# Stabilization progress: 3.485493253712504% complete
# Stabilization progress: 3.485493253712504% complete
# Stabilization progress: 3.5014087480216927% complete
# Stabilization progress: 3.4536622650941253% complete
# Stabilization progress: 3.5014087480216927% complete
# Stabilization progress: 3.5014087480216927% complete
# Stabilization progress: 3.517324242330882% complete
# Stabilization progress: 3.4695777594033146% complete
# Stabilization progress: 3.517324242330882% complete
# Stabilization progress: 3.517324242330882% complete
# Stabilization progress: 3.533239736640071% complete
# Stabilization progress: 3.485493253712504% complete
# Stabilization progress: 3.533239736640071% complete
# Stabilization progress: 3.533239736640071% complete
# Stabilization progress: 3.549155230949261% complete
# Stabilization progress: 3.5014087480216927% complete
# Stabilization progress: 3.549155230949261% complete
# Stabilization progress: 3.549155230949261% complete
# Stabilization progress: 3.517324242330882% complete
# Stabilization progress: 3.5650707252584497% complete
# Stabilization progress: 3.5650707252584497% complete
# Stabilization progress: 3.5650707252584497% complete
# Stabilization progress: 3.580986219567639% complete
# Stabilization progress: 3.533239736640071% complete
# Stabilization progress: 3.580986219567639% complete
# Stabilization progress: 3.580986219567639% complete
# Stabilization progress: 3.596901713876828% complete
# Stabilization progress: 3.549155230949261% complete
# Stabilization progress: 3.596901713876828% complete
# Stabilization progress: 3.596901713876828% complete
# Stabilization progress: 3.5650707252584497% complete
# Stabilization progress: 3.612817208186017% complete
# Stabilization progress: 3.612817208186017% complete
# Stabilization progress: 3.612817208186017% complete
# Stabilization progress: 3.580986219567639% complete
# Stabilization progress: 3.6287327024952063% complete
# Stabilization progress: 3.6287327024952063% complete
# Stabilization progress: 3.6287327024952063% complete
# ...
# Stabilization progress: 59.683103659462525% complete
# Stabilization progress: 60.12873750011973% complete
# Stabilization progress: 60.701695295250445% complete
# Stabilization progress: 60.46296288061265% complete
# Stabilization progress: 60.144652994428924% complete
# Stabilization progress: 59.6990191537717% complete
# Stabilization progress: 60.71761078955963% complete
# Stabilization progress: 60.16056848873811% complete
# Stabilization progress: 60.47887837492184% complete
# Stabilization progress: 59.714934648080884% complete
# Stabilization progress: 60.73352628386882% complete
# Stabilization progress: 60.17648398304729% complete
# Stabilization progress: 60.494793869231025% complete
# Stabilization progress: 59.73085014239008% complete
# Stabilization progress: 60.749441778178% complete
# Stabilization progress: 60.51070936354021% complete
# Stabilization progress: 59.74676563669926% complete
# Stabilization progress: 60.19239947735648% complete
# Stabilization progress: 60.765357272487186% complete
# Stabilization progress: 60.5266248578494% complete
# Stabilization progress: 59.76268113100844% complete
# Stabilization progress: 60.208314971665665% complete
# Stabilization progress: 60.78127276679638% complete
# Stabilization progress: 59.77859662531764% complete
# Stabilization progress: 60.54254035215858% complete
# Stabilization progress: 60.22423046597485% complete
# Stabilization progress: 60.79718826110556% complete
# Stabilization progress: 59.794512119626816% complete
# Stabilization progress: 60.558455846467766% complete
# Stabilization progress: 60.81310375541476% complete
# Stabilization progress: 60.24014596028404% complete
# Stabilization progress: 59.810427613936014% complete
# Stabilization progress: 60.574371340776956% complete
# Stabilization progress: 60.829019249723935% complete
# Stabilization progress: 60.25606145459322% complete
# Stabilization progress: 59.8263431082452% complete
# Stabilization progress: 60.84493474403312% complete
# Stabilization progress: 60.59028683508614% complete
# Stabilization progress: 60.27197694890242% complete
# Stabilization progress: 59.842258602554374% complete
# Stabilization progress: 60.86085023834231% complete
# Stabilization progress: 60.2878924432116% complete
# Stabilization progress: 60.60620232939533% complete
# Stabilization progress: 59.85817409686357% complete
# Stabilization progress: 60.622117823704514% complete
# Stabilization progress: 60.87676573265149% complete
# Stabilization progress: 60.30380793752078% complete
# Stabilization progress: 59.874089591172755% complete
# Stabilization progress: 60.6380333180137% complete
# Stabilization progress: 60.892681226960676% complete
# Stabilization progress: 60.31972343182998% complete
# Stabilization progress: 59.890005085481945% complete
# Stabilization progress: 60.90859672126987% complete
# Stabilization progress: 60.65394881232289% complete
# Stabilization progress: 60.335638926139154% complete
# Stabilization progress: 59.90592057979113% complete
# Stabilization progress: 60.66986430663207% complete
# Stabilization progress: 60.92451221557905% complete
# Stabilization progress: 59.92183607410031% complete
# Stabilization progress: 60.35155442044835% complete
# Stabilization progress: 59.9377515684095% complete
# Stabilization progress: 60.685779800941255% complete
# Stabilization progress: 60.94042770988825% complete
# Stabilization progress: 60.367469914757535% complete
# Stabilization progress: 60.956343204197424% complete
# Stabilization progress: 60.701695295250445% complete
# Stabilization progress: 59.95366706271869% complete
# Stabilization progress: 60.38338540906671% complete
# Stabilization progress: 60.97225869850661% complete
# Stabilization progress: 59.96958255702787% complete
# Stabilization progress: 60.71761078955963% complete
# Stabilization progress: 60.39930090337591% complete
# Stabilization progress: 60.988174192815805% complete
# Stabilization progress: 60.41521639768509% complete
# Stabilization progress: 59.98549805133706% complete
# Stabilization progress: 60.73352628386882% complete
# Stabilization progress: 61.00408968712499% complete
# Stabilization progress: 60.749441778178% complete
# Stabilization progress: 60.001413545646244% complete
# Stabilization progress: 60.43113189199427% complete
# Stabilization progress: 61.020005181434165% complete
# Stabilization progress: 60.765357272487186% complete
# Stabilization progress: 60.017329039955435% complete
# Stabilization progress: 60.44704738630347% complete
# Stabilization progress: 61.03592067574336% complete
# Stabilization progress: 60.03324453426462% complete
# Stabilization progress: 60.78127276679638% completeStabilization progress: 60.46296288061265% complete
#
# Stabilization progress: 61.05183617005254% complete
# Stabilization progress: 60.79718826110556% complete
# Stabilization progress: 60.47887837492184% complete
# Stabilization progress: 60.0491600285738% complete
# Stabilization progress: 61.06775166436174% complete
# Stabilization progress: 60.81310375541476% complete
# Stabilization progress: 60.494793869231025% complete
# Stabilization progress: 60.06507552288299% complete
# Stabilization progress: 61.08366715867092% complete
# Stabilization progress: 60.829019249723935% complete
# Stabilization progress: 60.080991017192176% complete
# Stabilization progress: 60.51070936354021% complete
# Stabilization progress: 61.099582652980104% complete
# Stabilization progress: 60.84493474403312% complete
# Stabilization progress: 60.09690651150136% complete
# Stabilization progress: 60.5266248578494% complete
# Stabilization progress: 61.115498147289294% complete
# Stabilization progress: 60.86085023834231% complete
# Stabilization progress: 60.11282200581055% complete
# Stabilization progress: 60.54254035215858% complete
# Stabilization progress: 61.13141364159848% complete
# Stabilization progress: 60.87676573265149% complete
# Stabilization progress: 60.12873750011973% complete
# Stabilization progress: 60.558455846467766% complete
# Stabilization progress: 60.892681226960676% complete
# Stabilization progress: 61.14732913590767% complete
# Stabilization progress: 60.574371340776956% complete
# Stabilization progress: 60.144652994428924% complete
# Stabilization progress: 61.16324463021685% complete
# Stabilization progress: 60.90859672126987% complete
# Stabilization progress: 60.59028683508614% complete
# Stabilization progress: 60.16056848873811% complete
# Stabilization progress: 60.92451221557905% complete
# Stabilization progress: 61.179160124526035% complete
# Stabilization progress: 60.17648398304729% complete
# Stabilization progress: 60.60620232939533% complete
# Stabilization progress: 60.94042770988825% complete
# Stabilization progress: 61.195075618835226% complete
# Stabilization progress: 61.21099111314441% complete
# Stabilization progress: 60.19239947735648% complete
# Stabilization progress: 60.622117823704514% completeStabilization progress: 60.956343204197424% complete
#
# Stabilization progress: 60.208314971665665% complete
# Stabilization progress: 60.97225869850661% complete
# Stabilization progress: 60.6380333180137% complete
# Stabilization progress: 61.22690660745359% complete
# Stabilization progress: 60.988174192815805% complete
# Stabilization progress: 60.22423046597485% complete
# Stabilization progress: 60.65394881232289% complete
# Stabilization progress: 61.24282210176278% complete
# Stabilization progress: 61.00408968712499% complete
# Stabilization progress: 61.25873759607197% complete
# Stabilization progress: 60.24014596028404% complete
# Stabilization progress: 60.66986430663207% complete
# Stabilization progress: 61.020005181434165% complete
# Stabilization progress: 60.25606145459322% complete
# Stabilization progress: 61.27465309038116% complete
# Stabilization progress: 60.685779800941255% complete
# Stabilization progress: 61.03592067574336% complete
# Stabilization progress: 61.29056858469034% complete
# Stabilization progress: 60.701695295250445% complete
# Stabilization progress: 60.27197694890242% complete
# Stabilization progress: 61.05183617005254% complete
# Stabilization progress: 61.306484078999524% complete
# Stabilization progress: 60.71761078955963% complete
# Stabilization progress: 60.2878924432116% complete
# Stabilization progress: 61.06775166436174% complete
# Stabilization progress: 61.322399573308715% complete
# Stabilization progress: 60.73352628386882% complete
# Stabilization progress: 60.30380793752078% complete
# Stabilization progress: 61.08366715867092% complete
# Stabilization progress: 61.3383150676179% complete
# Stabilization progress: 60.31972343182998% complete
# Stabilization progress: 60.749441778178% complete
# Stabilization progress: 61.099582652980104% complete
# Stabilization progress: 61.35423056192708% complete
# Stabilization progress: 60.765357272487186% complete
# Stabilization progress: 60.335638926139154% complete
# Stabilization progress: 61.115498147289294% complete
# Stabilization progress: 61.37014605623627% complete
# Stabilization progress: 60.78127276679638% complete
# Stabilization progress: 61.13141364159848% complete
# Stabilization progress: 60.35155442044835% complete
# Stabilization progress: 61.386061550545456% complete
# Stabilization progress: 60.79718826110556% complete
# Stabilization progress: 61.14732913590767% complete
# Stabilization progress: 60.367469914757535% complete
# Stabilization progress: 61.40197704485465% complete
# Stabilization progress: 60.38338540906671% complete
# Stabilization progress: 60.81310375541476% complete
# Stabilization progress: 61.16324463021685% complete
# Stabilization progress: 61.41789253916383% complete
# Stabilization progress: 60.829019249723935% complete
# Stabilization progress: 60.39930090337591% complete
# Stabilization progress: 61.179160124526035% complete
# Stabilization progress: 61.433808033473014% complete
# Stabilization progress: 61.195075618835226% complete
# Stabilization progress: 60.41521639768509% complete
# Stabilization progress: 60.84493474403312% complete
# Stabilization progress: 61.449723527782204% complete
# Stabilization progress: 60.86085023834231% complete
# Stabilization progress: 60.43113189199427% complete
# Stabilization progress: 61.21099111314441% complete
# Stabilization progress: 61.46563902209139% complete
# Stabilization progress: 60.87676573265149% complete
# Stabilization progress: 61.22690660745359% complete
# Stabilization progress: 60.44704738630347% complete
# Stabilization progress: 61.48155451640057% complete
# Stabilization progress: 60.892681226960676% complete
# Stabilization progress: 61.24282210176278% complete
# Stabilization progress: 61.49747001070976% complete
# Stabilization progress: 60.46296288061265% complete
# Stabilization progress: 60.90859672126987% complete
# Stabilization progress: 61.25873759607197% complete
# Stabilization progress: 60.47887837492184% complete
# Stabilization progress: 61.513385505018945% complete
# Stabilization progress: 60.92451221557905% complete
# Stabilization progress: 61.27465309038116% complete
# Stabilization progress: 60.494793869231025% complete
# Stabilization progress: 61.52930099932814% complete
# Stabilization progress: 60.94042770988825% complete
# Stabilization progress: 61.29056858469034% complete
# Stabilization progress: 60.51070936354021% complete
# Stabilization progress: 61.54521649363732% complete
# Stabilization progress: 60.956343204197424% complete
# Stabilization progress: 61.5611319879465% complete
# Stabilization progress: 61.306484078999524% complete
# Stabilization progress: 60.5266248578494% complete
# Stabilization progress: 60.97225869850661% complete
# Stabilization progress: 61.5770474822557% complete
# Stabilization progress: 61.322399573308715% complete
# Stabilization progress: 60.54254035215858% complete
# Stabilization progress: 60.988174192815805% complete
# Stabilization progress: 61.59296297656488% complete
# Stabilization progress: 61.3383150676179% complete
# Stabilization progress: 61.00408968712499% complete
# Stabilization progress: 60.558455846467766% complete
# Stabilization progress: 61.608878470874075% complete
# Stabilization progress: 61.35423056192708% complete
# Stabilization progress: 61.020005181434165% complete
# Stabilization progress: 60.574371340776956% complete
# Stabilization progress: 61.62479396518326% complete
# Stabilization progress: 61.37014605623627% complete
# Stabilization progress: 60.59028683508614% complete
# Stabilization progress: 61.03592067574336% complete
# Stabilization progress: 61.640709459492435% complete
# Stabilization progress: 61.386061550545456% complete
# Stabilization progress: 60.60620232939533% complete
# Stabilization progress: 61.05183617005254% complete
# Stabilization progress: 61.65662495380163% complete
# Stabilization progress: 61.40197704485465% complete
# Stabilization progress: 60.622117823704514% complete
# Stabilization progress: 61.06775166436174% complete
# Stabilization progress: 61.672540448110816% complete
# Stabilization progress: 61.41789253916383% complete
# Stabilization progress: 60.6380333180137% complete
# Stabilization progress: 61.08366715867092% complete
# Stabilization progress: 61.68845594241999% complete
# Stabilization progress: 61.433808033473014% complete
# Stabilization progress: 60.65394881232289% complete
# Stabilization progress: 61.099582652980104% complete
# Stabilization progress: 61.70437143672919% complete
# Stabilization progress: 61.449723527782204% complete
# Stabilization progress: 60.66986430663207% complete
# Stabilization progress: 61.115498147289294% complete
# Stabilization progress: 61.72028693103837% completeStabilization progress: 61.46563902209139% complete
#
# Stabilization progress: 60.685779800941255% complete
# Stabilization progress: 61.13141364159848% complete
# Stabilization progress: 61.736202425347564% complete
# Stabilization progress: 61.48155451640057% complete
# Stabilization progress: 60.701695295250445% complete
# Stabilization progress: 61.14732913590767% complete
# Stabilization progress: 61.75211791965675% complete
# Stabilization progress: 61.49747001070976% complete
# Stabilization progress: 60.71761078955963% complete
# Stabilization progress: 61.16324463021685% complete
# Stabilization progress: 61.76803341396593% complete
# Stabilization progress: 61.513385505018945% complete
# Stabilization progress: 60.73352628386882% complete
# Stabilization progress: 61.179160124526035% complete
# Stabilization progress: 61.78394890827512% complete
# Stabilization progress: 61.52930099932814% complete
# Stabilization progress: 60.749441778178% complete
# Stabilization progress: 61.195075618835226% complete
# Stabilization progress: 61.799864402584305% complete
# Stabilization progress: 61.54521649363732% complete
# Stabilization progress: 60.765357272487186% complete
# Stabilization progress: 61.21099111314441% complete
# Stabilization progress: 61.81577989689349% complete
# Stabilization progress: 61.5611319879465% complete
# Stabilization progress: 60.78127276679638% complete
# Stabilization progress: 61.83169539120268% complete
# Stabilization progress: 61.22690660745359% complete
# Stabilization progress: 61.5770474822557% complete
# Stabilization progress: 60.79718826110556% complete
# Stabilization progress: 61.84761088551186% complete
# Stabilization progress: 61.24282210176278% complete
# Stabilization progress: 61.59296297656488% complete
# Stabilization progress: 60.81310375541476% complete
# Stabilization progress: 61.86352637982105% complete
# Stabilization progress: 61.25873759607197% complete
# Stabilization progress: 61.608878470874075% complete
# Stabilization progress: 60.829019249723935% complete
# Stabilization progress: 61.87944187413024% complete
# Stabilization progress: 61.27465309038116% complete
# Stabilization progress: 61.62479396518326% complete
# Stabilization progress: 60.84493474403312% complete
# Stabilization progress: 61.89535736843942% complete
# Stabilization progress: 61.29056858469034% complete
# Stabilization progress: 61.640709459492435% complete
# Stabilization progress: 60.86085023834231% complete
# Stabilization progress: 61.91127286274861% complete
# Stabilization progress: 61.306484078999524% complete
# Stabilization progress: 61.65662495380163% complete
# Stabilization progress: 60.87676573265149% complete
# Stabilization progress: 61.927188357057794% complete
# Stabilization progress: 61.322399573308715% complete
